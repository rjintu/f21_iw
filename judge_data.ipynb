# %%
import pandas as pd

df = pd.read_stata("auburn_appct_stata/auburn_appct_stata.dta")

# pd.set_option('display.max_columns', None)

df1 = df[["name", "city", "state", "dcother", "gender", "race"]]
df1.head(40)
# Out:
#                         name    city  state  dcother  gender  race
# 0         Acheson, Marcus W.  3870.0   38.0      NaN       1     1
# 1            Adams, Arlin M.  3860.0   38.0      NaN       1     1
# 2            Adams, Elmer B.  2580.0   25.0      NaN       1     1
# 3          Ainsworth, Robert  1860.0   18.0      NaN       1     1
# 4         Alarcon, Arthur L.   550.0    5.0      NaN       1     3
# 5          Aldisert, Ruggero  3870.0   38.0      NaN       1     1
# 6            Aldrich, Bailey  2110.0   21.0      NaN       1     1
# 7      Alito, Samuel A., Jr.  3060.0   30.0      NaN       1     1
# 8            Allen, Florence  3530.0   35.0      NaN       2     1
# 9          Alschuler, Samuel  1325.0   13.0      NaN       1     1
# 10        Altimari, Frank X.  3285.0   32.0      NaN       1     1
# 11            Alvey, Richard  5110.0   51.0     20.0       1     1
# 12          Ambro, Thomas L.   880.0    8.0      NaN       1     1
# ...
